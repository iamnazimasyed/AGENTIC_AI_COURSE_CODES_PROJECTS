# %% [markdown]
# <a href="https://colab.research.google.com/github/iamnazimasyed/AGENTIC_AI_COURSE_CODES_PROJECTS/blob/main/image_to_text.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pytesseract

# %%
import pytesseract
from PIL import Image
img=Image.open("/content/Agenticaicourse.webp")
text=pytesseract.image_to_string(img)
print(text)
# Out:
#
#
# to write a long text ano
# save it as an image.
