# %% [markdown]
# <a href="https://colab.research.google.com/github/iamnazimasyed/AGENTIC_AI_COURSE_CODES_PROJECTS/blob/main/IMAGE_TO_EMOTION%26NATIONALITY%26COLOR%26REGION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install deepface
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.7/170.7 kB 8.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.0/212.0 kB 9.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.4/70.4 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 29.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.5/51.5 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 52.7 MB/s eta 0:00:00
# ...

# %%
from deepface import DeepFace
obj=DeepFace.analyze("/content/aiemotion.webp")
# Out:
# Action: emotion:   0%|          | 0/4 [00:00<?, ?it/s]
# 26-05-21 07:09:07 - 🔗 facial_expression_model_weights.h5 will be downloaded from https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5 to /root/.deepface/weights/facial_expression_model_weights.h5...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: /root/.deepface/weights/facial_expression_model_weights.h5
#
# 100%|██████████| 5.98M/5.98M [00:00<00:00, 106MB/s]
# Action: age:  25%|██▌       | 1/4 [00:00<00:02,  1.05it/s]
# 26-05-21 07:09:10 - 🔗 age_model_weights.h5 will be downloaded from https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5 to /root/.deepface/weights/age_model_weights.h5...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5
# To: /root/.deepface/weights/age_model_weights.h5
#
# ...

# %%
print(obj)
# Out:
# [{'emotion': {'angry': np.float32(0.026144477), 'disgust': np.float32(2.743705e-05), 'fear': np.float32(0.45738608), 'happy': np.float32(3.1880412), 'sad': np.float32(0.1769688), 'surprise': np.float32(0.07668865), 'neutral': np.float32(96.074745)}, 'dominant_emotion': 'neutral', 'region': {'x': 478, 'y': 111, 'w': 573, 'h': 573, 'left_eye': (859, 341), 'right_eye': (665, 329)}, 'face_confidence': 0.92, 'age': 23, 'gender': {'Woman': np.float32(0.013297635), 'Man': np.float32(99.986694)}, 'dominant_gender': 'Man', 'race': {'asian': np.float32(0.3974808), 'indian': np.float32(14.744444), 'black': np.float32(0.7990893), 'white': np.float32(12.283414), 'middle eastern': np.float32(54.292877), 'latino hispanic': np.float32(17.482698)}, 'dominant_race': 'middle eastern'}]
